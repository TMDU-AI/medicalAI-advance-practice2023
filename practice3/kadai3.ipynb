# %% [markdown]
# 1. (for文)
# 以下の%%%%を置き換えて、欲しい出力結果が得られるようにしてください.
# %の数は関係ありません
#
# 欲しい出力結果
# 0
# 5
# 10
# 15
# 20

# %%
for kadai3 in range(5):
  print(%%%% * 5)

# %% [markdown]
# 2. (for文) 下の%%%%を置き換えて、下の出力結果が得られるようなリストdatasを作成してください

# %% [markdown]
# ![スクリーンショット 2023-10-24 8.59.42.png](data:image/png;base64,...)

# %%
# 文字のデータはシングルクォーテーションもしくはダブルクォーテーションで囲みます
# 例) "こんにちは" or 'こんにちは'
dates = [%%%%%%%%%%%%%]
for date in dates:
  print(date,"曜日は平日です")

# %% [markdown]
# 3. mnistのデータについて、テスト用データの11枚目から16枚目までを横に並べて下記のように図示出来るように、%%%を埋めて実行して下さい。

# %% [markdown]
# ![スクリーンショット 2023-10-24 8.54.43.png](data:image/png;base64,...)

# %%
# 先にこのセルを実行して下さい
from keras.datasets import mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()

# %%
# "#"はコメントで実行した際には無視されます
import matplotlib.pyplot as plt
# 無くても動きますが、plt.figure()は図を書く宣言です
# plt.figure(figsize=(x,y))で図の大きさを変えることが出来ます
plt.figure()
# range(num)だと0からnum未満まで
# range(num1,num2)だとnum1からnum2未満まで
for i in range(%%%,%%%):
  plt.subplot(%%%,%%%,%%%)
  plt.imshow(x_test[%%%],'gray')
plt.show()

# %% [markdown]
# 4. 自分の学籍番号となるように数字の画像を横一列に並べて下さい。(どの画像を用いても大丈夫です)

# %% [markdown]
# 5.テスト用データの20枚目の画像がどの数字であるかを、one-hot encodingで表示して下さい

# %% [markdown]
# 必ずファイル名を変えて(学籍番号_名前_3.ipynb)提出して下さい。締め切りを過ぎたもの、ファイル名が正しくないものは原則受け取りません。
