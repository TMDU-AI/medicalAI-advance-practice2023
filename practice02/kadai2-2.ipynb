# %% [markdown]
# 1. mnistのデータを読み込んで、それぞれx_train, y_train, x_test, y_testに代入して下さい。

# %% [markdown]
# 2. 学習用データの10枚目の画像が表す数字を出力して下さい。
#
# (正解の数字が出力されるようにセルに入力して、出力結果を表示して下さい)

# %% [markdown]
# 3. テスト用データの自分の学籍番号下4桁番目の正解ラベルは何か？
#
# 例)
# 学籍番号12345678→テスト用データの5678番目
#
# (正解の数字が出力されるようにセルに入力して、出力結果を表示して下さい)

# %% [markdown]
# 4. テスト用データの自分の学籍番号下4桁番目の画像の配列の、11行目9列目の数字を出力して下さい

# %% [markdown]
# mnistではなく、fashion_mnistを読み込んで下さい(下記を実行して下さい)
#
# mnist→fashion_mnist

# %% [markdown]
# ![スクリーンショット 2023-07-18 18.54.38.png](data:image/png;base64,...)

# %%
# このセルを実行して下さい
from keras.datasets import fashion_mnist
(x_train, y_train),(x_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# 5. 学習用データの枚数、画像サイズは何か

# %%
# このセルにコードを入力して調べて下さい

# %%
# 結果を$$$を書き換えて出力して下さい
print("学習用データは$$$枚で、画像サイズは$$$×$$$"です)

# %% [markdown]
# 6. テスト用データの枚数、画像サイズは何か

# %%
# このセルにコードを入力して調べて下さい

# %%
# 結果を$$$を書き換えて出力して下さい
print("テスト用データは$$$枚で、画像サイズは$$$×$$$"です)

# %% [markdown]
# 7. 学習用データの自分の学籍番号下4桁番目の正解の数字は何か？
#
# fashion_mnistは洋服の種類によって正解ラベルが0から9の数字で与えられています。
# (上の図参照)
#
# 例) 学籍番号12345678→学習用データの5678番目
# (正解の数字が出力されるようにセルに入力して、出力結果を表示して下さい)

# %% [markdown]
# 8. またその画像の配列の13行目8列目の数字を出力して下さい

# %% [markdown]
# 必ずファイル名を変えて(学籍番号_名前_1.ipynb)提出して下さい。締め切りを過ぎたもの、ファイル名が正しくないものは原則受け取りません。
