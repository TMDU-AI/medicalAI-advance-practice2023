# %% [markdown]
# 演習1 下のプログラムを実行して下さい

# %%
1 + 3

# %% [markdown]
# 演習2 下に 84356と5343の掛け算を実行してください

# %% [markdown]
# 演習3 下の#####をを書き換えて埋めて"こんにちは"が出力されるようにして下さい

# %%
hello = #####
hello

# %% [markdown]
# 演習4 自分の学籍番号と名前をそれぞれ変数a,bに代入して、"私の名前はb(自分の名前)で学籍番号はa(自分の名前)です"出力して下さい(参考資料)

# %% [markdown]
# 演習5 下の###を書き換えて、(x,y)=(1,5),(3,10),(5,15),(7,20),(9,25)の5点を通る折れ線を作図して下さい(matplotlibを使用します(「医療とAI・ビッグデータ入門第一回の復習))
# 図のタイトルやx軸、y軸の名前は不要です。(注意：下の図は折れ線ではありません)

# %% [markdown]
# ![スクリーンショット 2023-07-03 8.20.48.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
x = #####
y = #####
plt.figure()
plt.#####
plt.show()

# %% [markdown]
# 必ずファイル名を変えて(学籍番号_名前_1.ipynb)提出して下さい。締め切りを過ぎたもの、ファイル名が正しくないものは原則受け取りません。
