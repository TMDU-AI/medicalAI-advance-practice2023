# %% [markdown]
# 1. 入力層の変数の数が784、中間層のニューロンの数が8つ、出力層のニューロンの数が1つのMLPでは
# パラメータ(重みとバイアス)はいくつになるか、計算または算出して答えが出力されるように、%%%%を埋めてください。
# セルは%%%%のみを置き換えて、結果を出力してください。
# セルで実行しながら考えたい場合は下の下書き欄を使ってください(下書きの内容は採点対象外)

# %%
print("パラメータの総数は:",%%%%,"個")

# %% [markdown]
# 2. 入力層の変数の数が60、中間層の1つ目のニューロンの数が5個、中間層の2つ目のニューロンの数を3つ、
# 出力層のニューロンの数が5つのMLPでは、パラメータ(重みとバイアス)はいくつになるか、計算または算出して答えが出力されるように、%%%%を埋めてください。

# %%
print("パラメータの総数は:",%%%%,"個")

# %% [markdown]
# 3. 損失関数と最適化関数(最適化アルゴリズム)について、謝っているものはどれか.
#    a. 損失関数は予測結果と正解の誤差を計算する関数である.
#    b. 最適化アルゴリズムはReLU関数がよく使われる
#    c. 最適化アルゴリズムは重みとバイアスを更新する手法である.
#    d. 学習は損失関数の値が小さくなるように重みとバイアスを変えていく

# %%
# a or b or c or d
print("正解は%%")

# %% [markdown]
# 4. mnistではなくfashion_mnistを読み込んで、MLPを実施してください.
# (モデルの設計や学習のエポック数など、途中の書き方は自由).
# テスト用画像の5枚目の予測結果を出力してください

# %% [markdown]
# ![スクリーンショット 2023-11-02 3.11.49.png](data:image/png;base64,...)

# %%
#ここに読み込みから前処理までを書いてください

# %%
#ここにニューラルネットワークを書いてください

# %%
#ここで学習を行ってください

# %%
#ここに予測を書いてください

# %%
# 最後の予測結果を書いてください(%%%%をAnkle bootなどに置き換えて出力してください)
print("テスト用画像の5枚目の画像は%%%%です")

# %% [markdown]
# ### 下書きやメモはこれより下を使ってください
